# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulpanigrahy650-droid/Dmpm_Lab/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kmeans vs Kmedoid

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
rows = int(input("enter no of rows:"))
cols = int(input("enter no of cols: "))

matrix = []
for i in range(rows):
  row = list(map(int,input("enter elements of rows :").split()))
  matrix.append(row)

x = np.array(matrix)

print(x)
# Out:
# enter no of rows:6
# enter no of cols: 2
# enter elements of rows :2 3
# enter elements of rows :3 4
# enter elements of rows :4 3
# enter elements of rows :10 11
# enter elements of rows :11 12
# enter elements of rows :12 11
# [[ 2  3]
#  [ 3  4]
#  [ 4  3]
#  [10 11]
#  [11 12]
#  [12 11]]

# %%
plt.scatter(x=x[:,0],y=x[:,1])

# %%
kmeans = KMeans(n_clusters=2,random_state=42,n_init=10)
labels = kmeans.fit_predict(x)

print("kmeans centroid")
print(kmeans.cluster_centers_)

plt.figure(figsize=(8,6))

plt.scatter(x=x[:,0],y=x[:,1],c=labels,marker="x",s=200)
plt.xlabel("x")
plt.ylabel("y")
plt.title("kmeans")
# Out:
# kmeans centroid
# [[ 3.          3.33333333]
#  [11.         11.33333333]]
# Text(0.5, 1.0, 'kmeans')

# %% [markdown]
# kmedoid

# %%
import numpy as np

# %%
rows = int(input("enter no rows :"))
cols = int(input("enter no cols:"))

matrix=[]
for i in range(rows):
  row = list(map(int,input("enter no rows :").split()))
  matrix.append(row)

x = np.array(matrix)

# %%
k = 2
medoid_indices =[]

distances = np.zeros(len(x),k)
for i in range(len(x)):
  for j in range(k):
    distances[i,j] = np.lingalg.norm
